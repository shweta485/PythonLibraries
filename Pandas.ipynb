# %%
# !pip install pandas

# %%
import pandas as pd

# %% [raw]
# DataFrame
# Series

# %%
df = pd.read_csv("C:\\Users\\thora\\Documents\\student2.csv.xls")

# %%
df
# Out:
#        name  gmat  gpa  exp  admitted country
# 0     samir   780  4.0    3         1     Ind
# 1   kaushal   750  3.9    4         1     Ind
# 2    nandan   690  3.3    3         0     Ind
# 3     ankit   710  3.7    5         1      us
# 4   deepika   680  3.9    4         0     Ind
# 5    kshama   730  3.7    6         1     Ind
# 6    gaurav   690  2.3    1         0      us
# 7      john   720  3.3    4         1      us
# 8      nida   740  3.3    5         1     Ind
# 9     samir   690  1.7    1         0     Ind
# 10  kaushal   610  2.7    3         0     Ind
# 11   nandan   690  3.7    5         1     Ind
# 12    ankit   710  3.7    6         1      us
# 13  deepika   680  3.3    4         0     Ind
# 14   kshama   770  3.3    3         1     Ind
# 15   gaurav   510  3.0    1         0     Ind
# 16     john   580  2.7    4         0     Ind
# 17     nida   650  3.7    6         1     Ind
# 18    samir   540  2.7   24         0     Ind
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (42, 6)

# %%
df.ndim
# Out:
# 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      42 non-null     object
#  1   gmat      42 non-null     int64
#  2   gpa       42 non-null     float64
#  3   exp       42 non-null     int64
#  4   admitted  42 non-null     int64
#  5   country   42 non-null     object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 2.1+ KB

# %%
#  It Returns the header row and the first 10 rows, or the specified number of rows

# %%
df.head()
# Out:
#       name  gmat  gpa  exp  admitted country
# 0    samir   780  4.0    3         1     Ind
# 1  kaushal   750  3.9    4         1     Ind
# 2   nandan   690  3.3    3         0     Ind
# 3    ankit   710  3.7    5         1      us
# 4  deepika   680  3.9    4         0     Ind

# %%
#  It Returns the footer row and the last 10 rows, or the specified number of rows

# %%
df.head(10)
# Out:
#       name  gmat  gpa  exp  admitted country
# 0    samir   780  4.0    3         1     Ind
# 1  kaushal   750  3.9    4         1     Ind
# 2   nandan   690  3.3    3         0     Ind
# 3    ankit   710  3.7    5         1      us
# 4  deepika   680  3.9    4         0     Ind
# 5   kshama   730  3.7    6         1     Ind
# 6   gaurav   690  2.3    1         0      us
# 7     john   720  3.3    4         1      us
# 8     nida   740  3.3    5         1     Ind
# 9    samir   690  1.7    1         0     Ind

# %%
df.tail()
# Out:
#        name  gmat  gpa  exp  admitted country
# 37  kaushal   580  3.3    1         0     Ind
# 38   nandan   590  1.7    4         0     Ind
# 39    ankit   690  3.7    5         1      us
# 40  deepika   690  3.7    5         1     Ind
# 41   kshama   690  3.7    5         1     Ind

# %%
df.tail(10)
# Out:
#        name  gmat  gpa  exp  admitted country
# 32   kshama   660  4.0    4         1     Ind
# 33   gaurav   660  3.3    6         1     Ind
# 34     john   680  3.3    5         1     Ind
# 35     nida   650  2.3    1         0     Ind
# 36    samir   670  2.7    2         0      us
# 37  kaushal   580  3.3    1         0     Ind
# 38   nandan   590  1.7    4         0     Ind
# 39    ankit   690  3.7    5         1      us
# 40  deepika   690  3.7    5         1     Ind
# 41   kshama   690  3.7    5         1     Ind

# %%
#  It will be Returns a random selection elements

# %%
df.sample()
# Out:
#      name  gmat  gpa  exp  admitted country
# 39  ankit   690  3.7    5         1      us

# %%
df.sample(6)
# Out:
#        name  gmat  gpa  exp  admitted country
# 29   nandan   660  3.3    5         1      us
# 5    kshama   730  3.7    6         1     Ind
# 3     ankit   710  3.7    5         1      us
# 1   kaushal   750  3.9    4         1     Ind
# 17     nida   650  3.7    6         1     Ind
# 23   kshama   550  2.7    1         0     Ind

# %%
df[14:35]
# Out:
#        name  gmat  gpa  exp  admitted country
# 14   kshama   770  3.3    3         1     Ind
# 15   gaurav   510  3.0    1         0     Ind
# 16     john   580  2.7    4         0     Ind
# 17     nida   650  3.7    6         1     Ind
# 18    samir   540  2.7   24         0     Ind
# 19  kaushal   590  2.3    3         0     Ind
# 20   nandan   620  3.3    2         1      us
# 21    ankit   600  2.0    1         0     Ind
# 22  deepika   550  2.3    4         0     Ind
# 23   kshama   550  2.7    1         0     Ind
# 24   gaurav   570  3.0    2         0      us
# 25     john   670  3.3    6         1     Ind
# 26     nida   660  3.7    4         1     Ind
# 27    samir   580  2.3    2         0     Ind
# 28  kaushal   650  3.7    6         1     Ind
# 29   nandan   660  3.3    5         1      us
# 30    ankit   640  3.0    1         0     Ind
# 31  deepika   620  2.7    2         0     Ind
# 32   kshama   660  4.0    4         1     Ind
# ...

# %%
df[:40]
# Out:
#        name  gmat  gpa  exp  admitted country
# 0     samir   780  4.0    3         1     Ind
# 1   kaushal   750  3.9    4         1     Ind
# 2    nandan   690  3.3    3         0     Ind
# 3     ankit   710  3.7    5         1      us
# 4   deepika   680  3.9    4         0     Ind
# 5    kshama   730  3.7    6         1     Ind
# 6    gaurav   690  2.3    1         0      us
# 7      john   720  3.3    4         1      us
# 8      nida   740  3.3    5         1     Ind
# 9     samir   690  1.7    1         0     Ind
# 10  kaushal   610  2.7    3         0     Ind
# 11   nandan   690  3.7    5         1     Ind
# 12    ankit   710  3.7    6         1      us
# 13  deepika   680  3.3    4         0     Ind
# 14   kshama   770  3.3    3         1     Ind
# 15   gaurav   510  3.0    1         0     Ind
# 16     john   580  2.7    4         0     Ind
# 17     nida   650  3.7    6         1     Ind
# 18    samir   540  2.7   24         0     Ind
# ...

# %%
df[14:]
# Out:
#        name  gmat  gpa  exp  admitted country
# 14   kshama   770  3.3    3         1     Ind
# 15   gaurav   510  3.0    1         0     Ind
# 16     john   580  2.7    4         0     Ind
# 17     nida   650  3.7    6         1     Ind
# 18    samir   540  2.7   24         0     Ind
# 19  kaushal   590  2.3    3         0     Ind
# 20   nandan   620  3.3    2         1      us
# 21    ankit   600  2.0    1         0     Ind
# 22  deepika   550  2.3    4         0     Ind
# 23   kshama   550  2.7    1         0     Ind
# 24   gaurav   570  3.0    2         0      us
# 25     john   670  3.3    6         1     Ind
# 26     nida   660  3.7    4         1     Ind
# 27    samir   580  2.3    2         0     Ind
# 28  kaushal   650  3.7    6         1     Ind
# 29   nandan   660  3.3    5         1      us
# 30    ankit   640  3.0    1         0     Ind
# 31  deepika   620  2.7    2         0     Ind
# 32   kshama   660  4.0    4         1     Ind
# ...

# %%
d ={'cars':["honda","bmw","tesla"],
    'years':[5,7,6]}

# %%
# Creating DataFrame.

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#     cars  years
# 0  honda      5
# 1    bmw      7
# 2  tesla      6

# %%
df = pd.DataFrame(d,index = [1,2,3])

# %%
df
# Out:
#     cars  years
# 1  honda      5
# 2    bmw      7
# 3  tesla      6

# %%
s = [11,12,13]

# %%
df = pd.DataFrame(d,index = s)

# %%
df
# Out:
#      cars  years
# 11  honda      5
# 12    bmw      7
# 13  tesla      6

# %%
a = ["honda","bmw","tesla"]

# %%
# Creating Series

# %%
df1 = pd.Series(a)

# %%
df1
# Out:
# 0    honda
# 1      bmw
# 2    tesla
# dtype: object

# %%
type(df1)
# Out:
# pandas.core.series.Series

# %%
speed = [120,200,333]

# %%
df1 = pd.Series(speed,name ="speed",index = [1,2,3])

# %%
df1
# Out:
# 1    120
# 2    200
# 3    333
# Name: speed, dtype: int64

# %%
df = pd.read_csv("C:\\Users\\thora\\Documents\\dirtydata.csv")

# %%
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.0       130     409.1
# 1         60  '2020/12/02'  117.0       145     479.0
# 2         60  '2020/12/03'  103.0       135     340.0
# 3         45  '2020/12/04'  109.0       175     282.4
# 4         45  '2020/12/05'  117.0       148     406.0
# 5         60  '2020/12/06'  102.0       127     300.0
# 6         60  '2020/12/07'  110.0       136     374.0
# 7        450  '2020/12/08'  104.0       134     253.3
# 8         30  '2020/12/09'  109.0       133     195.1
# 9         60  '2020/12/10'   98.0       124     269.0
# 10        60  '2020/12/11'  103.0       147     329.3
# 11        60  '2020/12/12'  100.0       120     250.7
# 12        60  '2020/12/12'  100.0       120     250.7
# 13        60  '2020/12/13'    NaN       128     345.3
# 14        60  '2020/12/14'  104.0       132     379.3
# 15        60  '2020/12/15'   98.0       123     275.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     31 non-null     float64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 1.4+ KB

# %%
#  This is use to Finds NULL values

# %%
df.isnull()
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories
# 0      False  False  False     False     False
# 1      False  False  False     False     False
# 2      False  False  False     False     False
# 3      False  False  False     False     False
# 4      False  False  False     False     False
# 5      False  False  False     False     False
# 6      False  False  False     False     False
# 7      False  False  False     False     False
# 8      False  False  False     False     False
# 9      False  False  False     False     False
# 10     False  False  False     False     False
# 11     False  False  False     False     False
# 12     False  False  False     False     False
# 13     False  False   True     False     False
# 14     False  False  False     False     False
# 15     False  False  False     False     False
# 16     False  False  False     False     False
# 17     False  False  False     False     False
# 18     False  False  False     False      True
# ...

# %%
df.isnull().sum()
# Out:
# Duration    0
# Date        1
# Pulse       1
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   31.000000   32.000000   30.000000
# mean    68.437500  103.419355  128.500000  304.680000
# std     70.039591    7.948896   12.998759   66.003779
# min     30.000000   90.000000  101.000000  195.100000
# 25%     60.000000  100.000000  120.000000  250.700000
# 50%     60.000000  102.000000  127.500000  291.200000
# 75%     60.000000  106.500000  132.250000  343.975000
# max    450.000000  130.000000  175.000000  479.000000

# %%
# This is use to Drops all rows that contains NULL values

# %%
df.dropna()
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.0       130     409.1
# 1         60  '2020/12/02'  117.0       145     479.0
# 2         60  '2020/12/03'  103.0       135     340.0
# 3         45  '2020/12/04'  109.0       175     282.4
# 4         45  '2020/12/05'  117.0       148     406.0
# 5         60  '2020/12/06'  102.0       127     300.0
# 6         60  '2020/12/07'  110.0       136     374.0
# 7        450  '2020/12/08'  104.0       134     253.3
# 8         30  '2020/12/09'  109.0       133     195.1
# 9         60  '2020/12/10'   98.0       124     269.0
# 10        60  '2020/12/11'  103.0       147     329.3
# 11        60  '2020/12/12'  100.0       120     250.7
# 12        60  '2020/12/12'  100.0       120     250.7
# 14        60  '2020/12/14'  104.0       132     379.3
# 15        60  '2020/12/15'   98.0       123     275.0
# 16        60  '2020/12/16'   98.0       120     215.2
# ...

# %%
df.dropna(subset = ['Pulse','Calories'])
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.0       130     409.1
# 1         60  '2020/12/02'  117.0       145     479.0
# 2         60  '2020/12/03'  103.0       135     340.0
# 3         45  '2020/12/04'  109.0       175     282.4
# 4         45  '2020/12/05'  117.0       148     406.0
# 5         60  '2020/12/06'  102.0       127     300.0
# 6         60  '2020/12/07'  110.0       136     374.0
# 7        450  '2020/12/08'  104.0       134     253.3
# 8         30  '2020/12/09'  109.0       133     195.1
# 9         60  '2020/12/10'   98.0       124     269.0
# 10        60  '2020/12/11'  103.0       147     329.3
# 11        60  '2020/12/12'  100.0       120     250.7
# 12        60  '2020/12/12'  100.0       120     250.7
# 14        60  '2020/12/14'  104.0       132     379.3
# 15        60  '2020/12/15'   98.0       123     275.0
# 16        60  '2020/12/16'   98.0       120     215.2
# ...

# %%
# df1 = df.dropna(subset = ['Pulse','Calories'])

# %%
# OR

# %%
df.dropna(subset = ['Pulse','Calories'],inplace = True)

# %%
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.0       130     409.1
# 1         60  '2020/12/02'  117.0       145     479.0
# 2         60  '2020/12/03'  103.0       135     340.0
# 3         45  '2020/12/04'  109.0       175     282.4
# 4         45  '2020/12/05'  117.0       148     406.0
# 5         60  '2020/12/06'  102.0       127     300.0
# 6         60  '2020/12/07'  110.0       136     374.0
# 7        450  '2020/12/08'  104.0       134     253.3
# 8         30  '2020/12/09'  109.0       133     195.1
# 9         60  '2020/12/10'   98.0       124     269.0
# 10        60  '2020/12/11'  103.0       147     329.3
# 11        60  '2020/12/12'  100.0       120     250.7
# 12        60  '2020/12/12'  100.0       120     250.7
# 14        60  '2020/12/14'  104.0       132     379.3
# 15        60  '2020/12/15'   98.0       123     275.0
# 16        60  '2020/12/16'   98.0       120     215.2
# ...

# %%
df.isnull().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
df['current year'] = 2022

# %%
df.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories  current year
# 0        60  '2020/12/01'  110.0       130     409.1          2022
# 1        60  '2020/12/02'  117.0       145     479.0          2022
# 2        60  '2020/12/03'  103.0       135     340.0          2022
# 3        45  '2020/12/04'  109.0       175     282.4          2022
# 4        45  '2020/12/05'  117.0       148     406.0          2022

# %%
df2 = df['Pulse']

# %%
df2
# Out:
# 0     110.0
# 1     117.0
# 2     103.0
# 3     109.0
# 4     117.0
# 5     102.0
# 6     110.0
# 7     104.0
# 8     109.0
# 9      98.0
# 10    103.0
# 11    100.0
# 12    100.0
# 14    104.0
# 15     98.0
# 16     98.0
# 17    100.0
# 19    103.0
# 20     97.0
# 21    108.0
# 22    100.0
# 23    130.0
# 24    105.0
# 25    102.0
# 26    100.0
# 27     92.0
# 29    100.0
# 30    102.0
# 31     92.0
# Name: Pulse, dtype: float64

# %%
df.drop(['Pulse'],axis = 1,inplace =True)

# %%
df
# Out:
#     Duration          Date  Maxpulse  Calories  current year
# 0         60  '2020/12/01'       130     409.1          2022
# 1         60  '2020/12/02'       145     479.0          2022
# 2         60  '2020/12/03'       135     340.0          2022
# 3         45  '2020/12/04'       175     282.4          2022
# 4         45  '2020/12/05'       148     406.0          2022
# 5         60  '2020/12/06'       127     300.0          2022
# 6         60  '2020/12/07'       136     374.0          2022
# 7        450  '2020/12/08'       134     253.3          2022
# 8         30  '2020/12/09'       133     195.1          2022
# 9         60  '2020/12/10'       124     269.0          2022
# 10        60  '2020/12/11'       147     329.3          2022
# 11        60  '2020/12/12'       120     250.7          2022
# 12        60  '2020/12/12'       120     250.7          2022
# 14        60  '2020/12/14'       132     379.3          2022
# ...

# %%
df = pd.concat([df,df2],axis =1)

# %%
df.head()
# Out:
#    Duration          Date  Maxpulse  Calories  current year  Pulse
# 0        60  '2020/12/01'       130     409.1          2022  110.0
# 1        60  '2020/12/02'       145     479.0          2022  117.0
# 2        60  '2020/12/03'       135     340.0          2022  103.0
# 3        45  '2020/12/04'       175     282.4          2022  109.0
# 4        45  '2020/12/05'       148     406.0          2022  117.0

# %%
df.shape
# Out:
# (29, 6)
